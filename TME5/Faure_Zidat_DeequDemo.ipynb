# %% [markdown]
# * Master DAC - BDLE
# * Author: Mohamed-Amine Baazizi
# * Affiliation: LIP6 - Faculté des Sciences - Sorbonne Université
# * Email: mohamed-amine.baazizi@lip6.fr
# * October 2023

# %% [markdown]
# # Data quality verification

# %% [markdown]
# https://github.com/awslabs/deequ
#
# and its python-based version
#
# https://github.com/awslabs/python-deequ
#
# https://www.amazon.science/publications/automating-large-scale-data-quality-verification
#
# https://medium.com/codex/how-to-check-data-quality-in-pyspark-8a882e45bc95

# %% [markdown]
# ## Spark setup

# %%
# !pip install --upgrade -q pyspark==3.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.7/204.7 MB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 12.3 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done

# %%
# !pyspark --version
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.10/dist-packages/pyspark/jars/spark-unsafe_2.12-3.0.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.0.0
#       /_/
#
# Using Scala version 2.12.10, OpenJDK 64-Bit Server VM, 11.0.20.1
# Branch HEAD
# Compiled by user ubuntu on 2020-06-06T11:32:25Z
# Revision 3fdfce3120f307147244e5eaf46d61419a723d50
# Url https://gitbox.apache.org/repos/asf/spark.git
# Type --help for more information.

# %%
import os
os.environ["SPARK_VERSION"] = "3.0"

# %%
# !pip install  --upgrade -q pydeequ

# %%
from pyspark.sql import SparkSession, Row
import pydeequ

spark = SparkSession.builder\
    .master("local")\
    .appName("pyDeequ")\
    .config("spark.jars.packages", pydeequ.deequ_maven_coord)\
    .config("spark.jars.excludes", pydeequ.f2j_maven_coord)\
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7d2e888c1441:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyDeequ</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %% [markdown]
# ## usage

# %% [markdown]
# ### examples for the official doc

# %%
df = spark.sparkContext.parallelize([
            Row(a="foo", b=1, c=5),
            Row(a="bar", b=2, c=6),
            Row(a="baz", b=3, c=None)]).toDF()
df.show()
# Out:
# +---+---+----+
# |  a|  b|   c|
# +---+---+----+
# |foo|  1|   5|
# |bar|  2|   6|
# |baz|  3|null|
# +---+---+----+

# %% [markdown]
# #### analyzers

# %%
from pydeequ.analyzers import *

analysisResult = AnalysisRunner(spark) \
                    .onData(df) \
                    .addAnalyzer(Size()) \
                    .addAnalyzer(Completeness("b")) \
                    .run()
analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)
analysisResult_df.show()
# Out:
# +-------+--------+------------+-----+
# | entity|instance|        name|value|
# +-------+--------+------------+-----+
# |Dataset|       *|        Size|  3.0|
# | Column|       b|Completeness|  1.0|
# +-------+--------+------------+-----+

# %% [markdown]
# #### profile

# %%
from pydeequ.profiles import *

result = ColumnProfilerRunner(spark) \
    .onData(df) \
    .run()

for col, profile in result.profiles.items():
    print(profile)
# Out:
# StandardProfiles for column: a: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 3,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 3
#     },
#     "histogram": [
#         [
#             "baz",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "foo",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "bar",
#             1,
#             0.3333333333333333
#         ]
#     ]
# }
# NumericProfiles for column: b: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 3,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "1",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "2",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "3",
#             1,
#             0.3333333333333333
#         ]
#     ],
#     "kll": "None",
#     "mean": 2.0,
#     "maximum": 3.0,
#     "minimum": 1.0,
#     "sum": 6.0,
#     "stdDev": 0.816496580927726,
#     "approxPercentiles": []
# }
# NumericProfiles for column: c: {
#     "completeness": 0.6666666666666666,
#     "approximateNumDistinctValues": 2,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "5",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "NullValue",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "6",
#             1,
#             0.3333333333333333
#         ]
#     ],
#     "kll": "None",
#     "mean": 5.5,
#     "maximum": 6.0,
#     "minimum": 5.0,
#     "sum": 11.0,
#     "stdDev": 0.5,
#     "approxPercentiles": []
# }

# %% [markdown]
# #### constraint suggestion

# %%
from pydeequ.suggestions import *

suggestionResult = ConstraintSuggestionRunner(spark) \
             .onData(df) \
             .addConstraintRule(DEFAULT()) \
             .run()

# Constraint Suggestions in JSON format
print(suggestionResult)
# Out:
# {'constraint_suggestions': [{'constraint_name': 'CompletenessConstraint(Completeness(b,None))', 'column_name': 'b', 'current_value': 'Completeness: 1.0', 'description': "'b' is not null", 'suggesting_rule': 'CompleteIfCompleteRule()', 'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint', 'code_for_constraint': '.isComplete("b")'}, {'constraint_name': "ComplianceConstraint(Compliance('b' has no negative values,b >= 0,None))", 'column_name': 'b', 'current_value': 'Minimum: 1.0', 'description': "'b' has no negative values", 'suggesting_rule': 'NonNegativeNumbersRule()', 'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint', 'code_for_constraint': '.isNonNegative("b")'}, {'constraint_name': 'UniquenessConstraint(Uniqueness(List(b),None))', 'column_name': 'b', 'current_value': 'ApproxDistinctness: 1.0', 'description': "'b' is unique", 'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()', 'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint', 'code_for_constraint': '.isUnique("b")'}, {'constraint_name': 'CompletenessConstraint(Completeness(a,None))', 'column_name': 'a', 'current_value': 'Completeness: 1.0', 'description': "'a' is not null", 'suggesting_rule': 'CompleteIfCompleteRule()', 'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint', 'code_for_constraint': '.isComplete("a")'}, {'constraint_name': 'UniquenessConstraint(Uniqueness(List(a),None))', 'column_name': 'a', 'current_value': 'ApproxDistinctness: 1.0', 'description': "'a' is unique", 'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()', 'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint', 'code_for_constraint': '.isUnique("a")'}, {'constraint_name': "ComplianceConstraint(Compliance('c' has no negative values,c >= 0,None))", 'column_name': 'c', 'current_value': 'Minimum: 5.0', 'description': "'c' has no negative values", 'suggesting_rule': 'NonNegativeNumbersRule()', 'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint', 'code_for_constraint': '.isNonNegative("c")'}, {'constraint_name': 'CompletenessConstraint(Completeness(c,None))', 'column_name': 'c', 'current_value': 'Completeness: 0.6666666666666666', 'description': "'c' has less than 87% missing values", 'suggesting_rule': 'RetainCompletenessRule()', 'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness', 'code_for_constraint': '.hasCompleteness("c", lambda x: x >= 0.13, "It should be above 0.13!")'}]}

# %% [markdown]
# #### constraint verification

# %%
from pydeequ.checks import *
from pydeequ.verification import *

check = Check(spark, CheckLevel.Warning, "Review Check")

checkResult = VerificationSuite(spark) \
    .onData(df) \
    .addCheck(
        check.hasSize(lambda x: x >= 3) \
        .hasMin("b", lambda x: x == 0) \
        .isComplete("c")  \
        .isUnique("a")  \
        .isContainedIn("a", ["foo", "bar", "baz"]) \
        .isNonNegative("b")) \
    .run()

checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult)
checkResult_df.show()
# Out:
# Python Callback server started!
# +------------+-----------+------------+--------------------+-----------------+--------------------+
# |       check|check_level|check_status|          constraint|constraint_status|  constraint_message|
# +------------+-----------+------------+--------------------+-----------------+--------------------+
# |Review Check|    Warning|     Warning|SizeConstraint(Si...|          Success|                    |
# |Review Check|    Warning|     Warning|MinimumConstraint...|          Failure|Value: 1.0 does n...|
# |Review Check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.66666666...|
# |Review Check|    Warning|     Warning|UniquenessConstra...|          Success|                    |
# |Review Check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |Review Check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# +------------+-----------+------------+--------------------+-----------------+--------------------+

# %% [markdown]
# ### other examples

# %%
# !wget --no-verbose https://nuage.lip6.fr/s/89BG8HD9r3iE693/download/MLData.tgz -O /tmp/MLData.tgz
# Out:
# 2023-10-20 14:32:27 URL:https://nuage.lip6.fr/s/89BG8HD9r3iE693/download/MLData.tgz [19397838/19397838] -> "/tmp/MLData.tgz" [1]

# %%
# !tar -xzvf /tmp/MLData.tgz  --directory /tmp/
# Out:
# MLData/
# MLData/._loan.csv
# MLData/loan.csv
# MLData/autos.csv

# %%
# !rm  /tmp/MLData.tgz
# !rm /tmp/MLData/\._loan.csv
# !ls -hal /tmp/MLData
# Out:
# total 73M
# drwxr-xr-x 2  501 staff 4.0K Oct 20 14:32 .
# drwxrwxrwt 1 root root  4.0K Oct 20 14:32 ..
# -rw-r--r-- 1  501 staff  66M Jan  6  2022 autos.csv
# -rw-r--r-- 1  501 staff 6.8M Jan  6  2022 loan.csv

# %%
#load
dir = "/tmp/MLData/"
data =  spark.read\
            .format("csv").option("header", "true")\
            .option("inferSchema", "true")\
            .load(dir +"autos.csv")

# %%
data.count()
# Out:
# 371824

# %%
sample =data.sample(0.1)
sample.count()
# Out:
# 37093

# %%
sample.show()
# Out:
# +-------------------+--------------------+------+---------+-----+-------+-----------+------------------+---------+-------+--------+---------+-------------------+--------+-------------+-----------------+-------------------+------------+----------+-------------------+
# |        dateCrawled|                name|seller|offerType|price| abtest|vehicleType|yearOfRegistration|  gearbox|powerPS|   model|kilometer|monthOfRegistration|fuelType|        brand|notRepairedDamage|        dateCreated|nrOfPictures|postalCode|           lastSeen|
# +-------------------+--------------------+------+---------+-----+-------+-----------+------------------+---------+-------+--------+---------+-------------------+--------+-------------+-----------------+-------------------+------------+----------+-------------------+
# |2016-03-23 15:48:05|Ford_C_MAX_2.0_TD...|privat|  Angebot| 7550|   test|        bus|              2007|  manuell|    136|   c_max|   150000|                  6|  diesel|         ford|             nein|2016-03-23 00:00:00|           0|     88361|2016-04-05 18:45:11|
# |2016-03-27 11:38:00|BMW_530i_T�V_7/17...|privat|  Angebot| 3699|   test|  limousine|              2002|automatik|    231|     5er|   150000|                  7|  benzin|          bmw|             nein|2016-03-27 00:00:00|           0|     68309|2016-04-07 06:44:26|
# |2016-03-12 19:43:07|        Stadtflitzer|privat|  Angebot|  450|   test| kleinwagen|              1997|  manuell|     50|   arosa|   150000|                  5|  benzin|         seat|             nein|2016-03-12 00:00:00|           0|      9526|2016-03-21 01:46:11|
# |2016-03-13 20:40:49|MERCEDES_200E__T�...|privat|  Angebot|  500|   test|  limousine|              1990|  manuell|    118|  andere|   150000|                 10|  benzin|mercedes_benz|               ja|2016-03-13 00:00:00|           0|     35390|2016-03-13 20:40:49|
# |2016-03-08 07:54:46|           VW_Golf_3|privat|  Angebot|  350|   test|       null|              2016|  manuell|     75|    golf|   150000|                  4|  benzin|   volkswagen|             nein|2016-03-08 00:00:00|           0|     19386|2016-03-08 09:44:50|
# |2016-03-29 18:57:46|    Renault_Clio_1.4|privat|  Angebot|  590|control| kleinwagen|              1999|  manuell|     75|    clio|   125000|                  8|  benzin|      renault|             nein|2016-03-29 00:00:00|           0|     84180|2016-03-29 18:57:46|
# |2016-03-17 07:56:40|Opel_signum_1.9_cdti|privat|  Angebot| 4700|control|      kombi|              2005|  manuell|      0|  signum|   150000|                  0|    null|         opel|             nein|2016-03-17 00:00:00|           0|     88433|2016-04-04 04:17:32|
# |2016-03-21 01:59:07|BMW_435i_Sport_coupe|privat|  Angebot|39600|   test|      coupe|              2014|automatik|    306|  andere|    30000|                  7|  benzin|          bmw|             nein|2016-03-21 00:00:00|           0|     10435|2016-04-03 23:16:31|
# |2016-03-28 17:41:27|Opel_Astra_1.4_mi...|privat|  Angebot|10900|   test|       null|              2017|  manuell|    101|   astra|    50000|                  3|    null|         opel|             nein|2016-03-28 00:00:00|           0|     63607|2016-04-06 23:15:52|
# |2016-04-01 11:56:40|Opel_astra_g_coup...|privat|  Angebot| 1200|   test|      coupe|              2001|     null|      0|   astra|   150000|                  0|    null|         opel|             null|2016-04-01 00:00:00|           0|     47249|2016-04-07 08:46:07|
# |2016-03-11 23:42:53|Mercedes_Benz_E_2...|privat|  Angebot|20300|   test|  limousine|              2010|automatik|    204|e_klasse|    80000|                 12|  diesel|mercedes_benz|             nein|2016-03-11 00:00:00|           0|     51491|2016-04-03 01:26:23|
# |2016-03-10 11:44:54|Audi_A1_1.2_TFSI_...|privat|  Angebot|14500|   test| kleinwagen|              2013|  manuell|     86|      a1|    60000|                  4|  benzin|         audi|             nein|2016-03-10 00:00:00|           0|     31582|2016-04-07 01:15:35|
# |2016-03-16 16:44:10|Hyundai_Genesis_C...|privat|  Angebot|22999|control|      coupe|              2012|automatik|    303|  andere|    50000|                  4|  benzin|      hyundai|             nein|2016-03-16 00:00:00|           0|     88167|2016-04-06 20:18:22|
# |2016-03-16 23:25:21|     Honda_Civic_EG4|privat|  Angebot|  900|   test|       null|              1995|  manuell|     90|   civic|   150000|                  3|  benzin|        honda|             null|2016-03-16 00:00:00|           0|     35789|2016-03-19 17:19:00|
# |2016-03-12 22:57:58|Volkswagen_Polo_1...|privat|  Angebot| 9290|control| kleinwagen|              2010|  manuell|     86|    polo|    40000|                  5|  benzin|   volkswagen|             nein|2016-03-12 00:00:00|           0|     35630|2016-03-26 06:17:39|
# |2016-03-18 11:25:43|Mercedes_Benz_Kab...|privat|  Angebot| 7000|control|  limousine|              2003|  manuell|    120|     slk|   150000|                  5|  benzin|mercedes_benz|             nein|2016-03-18 00:00:00|           0|     57578|2016-03-23 08:44:31|
# |2016-04-03 15:58:09|Verkaufe_ein_topp...|privat|  Angebot| 4300|   test|  limousine|              2005|  manuell|     90|    golf|   150000|                 11|  diesel|   volkswagen|             null|2016-04-03 00:00:00|           0|     28779|2016-04-05 15:46:23|
# |2016-03-08 19:58:07|A_210_Evolution_A...|privat|  Angebot| 1499|   test| kleinwagen|              2002|  manuell|    140|a_klasse|   150000|                 10|    null|mercedes_benz|             nein|2016-03-08 00:00:00|           0|     16727|2016-03-10 17:44:36|
# |2016-03-16 12:53:29| Volvo_v40_mit_klima|privat|  Angebot|  300|   test|      kombi|              1998|  manuell|      0|     v40|   150000|                  6|  benzin|        volvo|             nein|2016-03-16 00:00:00|           0|     47137|2016-03-25 10:18:16|
# |2016-03-28 01:36:15|    Honda_Civic_1.4i|privat|  Angebot| 1500|   test|  limousine|              2000|  manuell|     75|   civic|   125000|                 11|  benzin|        honda|             nein|2016-03-28 00:00:00|           0|     12163|2016-04-02 11:47:57|
# +-------------------+--------------------+------+---------+-----+-------+-----------+------------------+---------+-------+--------+---------+-------------------+--------+-------------+-----------------+-------------------+------------+----------+-------------------+
# only showing top 20 rows

# %%
sample.printSchema()
# Out:
# root
#  |-- dateCrawled: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- seller: string (nullable = true)
#  |-- offerType: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- abtest: string (nullable = true)
#  |-- vehicleType: string (nullable = true)
#  |-- yearOfRegistration: integer (nullable = true)
#  |-- gearbox: string (nullable = true)
#  |-- powerPS: integer (nullable = true)
#  |-- model: string (nullable = true)
#  |-- kilometer: integer (nullable = true)
#  |-- monthOfRegistration: integer (nullable = true)
#  |-- fuelType: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- notRepairedDamage: string (nullable = true)
#  |-- dateCreated: string (nullable = true)
#  |-- nrOfPictures: integer (nullable = true)
#  |-- postalCode: integer (nullable = true)
#  |-- lastSeen: string (nullable = true)

# %% [markdown]
# #### Analyzers

# %%
# set these variables
_data = sample
_colName = "vehicleType"

#reuse from tutorial
from pydeequ.analyzers import *

analysisResult = AnalysisRunner(spark) \
                    .onData(_data) \
                    .addAnalyzer(Size()) \
                    .addAnalyzer(Completeness(_colName)) \
                    .addAnalyzer(CountDistinct(_colName)) \
                    .addAnalyzer(Distinctness(_colName))\
                    .run()

# %%
analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)
analysisResult_df.show(truncate=False)
# Out:
# +-------+-----------+-------------+---------------------+
# |entity |instance   |name         |value                |
# +-------+-----------+-------------+---------------------+
# |Dataset|*          |Size         |37093.0              |
# |Column |vehicleType|Completeness |0.9010055805677621   |
# |Column |vehicleType|CountDistinct|8.0                  |
# |Column |vehicleType|Distinctness |2.3937045570150505E-4|
# +-------+-----------+-------------+---------------------+

# %% [markdown]
# Now consider more metrics (consistency)

# %%
_targetColName = 'price'
_otherColName = 'powerPS'
analysisResult = AnalysisRunner(spark) \
                    .onData(_data) \
                    .addAnalyzer(Entropy(_colName))\
                    .addAnalyzer(Correlation(_otherColName,_targetColName))\
                    .run()

# %%
analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)
analysisResult_df.show(truncate=False)
# Out:
# +-----------+-------------+-----------+-------------------+
# |entity     |instance     |name       |value              |
# +-----------+-------------+-----------+-------------------+
# |Mutlicolumn|powerPS,price|Correlation|0.02011889664147869|
# |Column     |vehicleType  |Entropy    |1.7716931190362275 |
# +-----------+-------------+-----------+-------------------+

# %% [markdown]
# #### profile

# %%
from pydeequ.profiles import *

result = ColumnProfilerRunner(spark) \
    .onData(_data) \
    .run()

# %%
for col, profile in result.profiles.items():
   print(profile)
# Out:
# StandardProfiles for column: lastSeen: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 31610,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 37093
#     },
#     "histogram": null
# }
# StandardProfiles for column: name: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 28466,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 8,
#         "Unknown": 0,
#         "String": 37085
#     },
#     "histogram": null
# }
# NumericProfiles for column: yearOfRegistration: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 94,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "2014",
#             475,
#             0.012805650661849945
#         ],
#         [
#             "1965",
#             14,
#             0.0003774297037176826
#         ],
#         [
#             "1928",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2003",
#             1964,
#             0.052947995578680615
#         ],
#         [
#             "1950",
#             4,
#             0.00010783705820505216
#         ],
#         [
#             "1983",
#             51,
#             0.0013749224921144152
#         ],
#         [
#             "3200",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1971",
#             18,
#             0.00048526676192273474
#         ],
#         [
#             "1978",
#             23,
#             0.0006200630846790499
#         ],
#         [
#             "1961",
#             6,
#             0.00016175558730757825
#         ],
#         [
#             "1954",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "1997",
#             1518,
#             0.0409241635888173
#         ],
#         [
#             "1986",
#             68,
#             0.001833229989485887
#         ],
#         [
#             "6000",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "1975",
#             8,
#             0.00021567411641010433
#         ],
#         [
#             "2013",
#             598,
#             0.0161216402016553
#         ],
#         [
#             "1989",
#             143,
#             0.003855174830830615
#         ],
#         [
#             "2002",
#             1895,
#             0.051087806324643464
#         ],
#         [
#             "1920",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1993",
#             330,
#             0.008896557301916803
#         ],
#         [
#             "1968",
#             12,
#             0.0003235111746151565
#         ],
#         [
#             "1982",
#             20,
#             0.0005391852910252608
#         ],
#         [
#             "1943",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2018",
#             378,
#             0.010190602000377429
#         ],
#         [
#             "1991",
#             267,
#             0.0071981236351872325
#         ],
#         [
#             "1980",
#             64,
#             0.0017253929312808346
#         ],
#         [
#             "2007",
#             1791,
#             0.04828404281131211
#         ],
#         [
#             "1957",
#             3,
#             8.087779365378912e-05
#         ],
#         [
#             "2500",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2222",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2004",
#             1937,
#             0.05222009543579651
#         ],
#         [
#             "1960",
#             25,
#             0.0006739816137815761
#         ],
#         [
#             "1996",
#             1073,
#             0.028927290863505244
#         ],
#         [
#             "2015",
#             307,
#             0.008276494217237754
#         ],
#         [
#             "1953",
#             3,
#             8.087779365378912e-05
#         ],
#         [
#             "1964",
#             7,
#             0.0001887148518588413
#         ],
#         [
#             "2011",
#             1189,
#             0.03205456555145176
#         ],
#         [
#             "1910",
#             8,
#             0.00021567411641010433
#         ],
#         [
#             "2001",
#             2106,
#             0.05677621114495997
#         ],
#         [
#             "9999",
#             3,
#             8.087779365378912e-05
#         ],
#         [
#             "1958",
#             4,
#             0.00010783705820505216
#         ],
#         [
#             "1979",
#             26,
#             0.0007009408783328391
#         ],
#         [
#             "2008",
#             1671,
#             0.045048931065160544
#         ],
#         [
#             "1969",
#             18,
#             0.00048526676192273474
#         ],
#         [
#             "2012",
#             921,
#             0.02482948265171326
#         ],
#         [
#             "2019",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1999",
#             2272,
#             0.06125144906046963
#         ],
#         [
#             "1974",
#             24,
#             0.000647022349230313
#         ],
#         [
#             "1981",
#             32,
#             0.0008626964656404173
#         ],
#         [
#             "2005",
#             2264,
#             0.061035774944059526
#         ],
#         [
#             "1988",
#             101,
#             0.002722885719677567
#         ],
#         [
#             "8000",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "7100",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1992",
#             278,
#             0.007494675545251126
#         ],
#         [
#             "2010",
#             1250,
#             0.0336990806890788
#         ],
#         [
#             "2009",
#             1553,
#             0.04186773784811151
#         ],
#         [
#             "1959",
#             4,
#             0.00010783705820505216
#         ],
#         [
#             "1934",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1977",
#             18,
#             0.00048526676192273474
#         ],
#         [
#             "2000",
#             2357,
#             0.06354298654732699
#         ],
#         [
#             "1995",
#             948,
#             0.025557382794597364
#         ],
#         [
#             "1970",
#             40,
#             0.0010783705820505216
#         ],
#         [
#             "1985",
#             110,
#             0.0029655191006389345
#         ],
#         [
#             "1963",
#             12,
#             0.0003235111746151565
#         ],
#         [
#             "2016",
#             957,
#             0.02580001617555873
#         ],
#         [
#             "1938",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1948",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1952",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "4000",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1962",
#             9,
#             0.00024263338096136737
#         ],
#         [
#             "1984",
#             37,
#             0.0009974927883967324
#         ],
#         [
#             "1951",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1998",
#             1799,
#             0.04849971692772221
#         ],
#         [
#             "1937",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1967",
#             10,
#             0.0002695926455126304
#         ],
#         [
#             "1966",
#             19,
#             0.0005122260264739978
#         ],
#         [
#             "1972",
#             24,
#             0.000647022349230313
#         ],
#         [
#             "1956",
#             4,
#             0.00010783705820505216
#         ],
#         [
#             "1955",
#             3,
#             8.087779365378912e-05
#         ],
#         [
#             "1945",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1987",
#             76,
#             0.002048904105895991
#         ],
#         [
#             "7000",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1253",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "1000",
#             4,
#             0.00010783705820505216
#         ],
#         [
#             "5000",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "1994",
#             501,
#             0.013506591540182784
#         ],
#         [
#             "1990",
#             282,
#             0.007602512603456178
#         ],
#         [
#             "2017",
#             1014,
#             0.027336694254980726
#         ],
#         [
#             "2006",
#             2075,
#             0.05594047394387081
#         ],
#         [
#             "1973",
#             14,
#             0.0003774297037176826
#         ],
#         [
#             "1976",
#             29,
#             0.0007818186719866282
#         ]
#     ],
#     "kll": "None",
#     "mean": 2004.7508963955463,
#     "maximum": 9999.0,
#     "minimum": 1000.0,
#     "sum": 74362225.0,
#     "stdDev": 95.88743921766911,
#     "approxPercentiles": []
# }
# StandardProfiles for column: model: {
#     "completeness": 0.9454074892836923,
#     "approximateNumDistinctValues": 247,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 591,
#         "Unknown": 2025,
#         "String": 34477
#     },
#     "histogram": null
# }
# StandardProfiles for column: abtest: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 37093
#     },
#     "histogram": [
#         [
#             "test",
#             19116,
#             0.5153533011619443
#         ],
#         [
#             "control",
#             17977,
#             0.4846466988380557
#         ]
#     ]
# }
# NumericProfiles for column: powerPS: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 406,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 115.45855013075243,
#     "maximum": 20000.0,
#     "minimum": 0.0,
#     "sum": 4282704.0,
#     "stdDev": 199.11718427917157,
#     "approxPercentiles": []
# }
# StandardProfiles for column: fuelType: {
#     "completeness": 0.9107378750707681,
#     "approximateNumDistinctValues": 7,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 3311,
#         "String": 33782
#     },
#     "histogram": [
#         [
#             "andere",
#             22,
#             0.000593103820127787
#         ],
#         [
#             "NullValue",
#             3311,
#             0.08926212492923193
#         ],
#         [
#             "elektro",
#             8,
#             0.00021567411641010433
#         ],
#         [
#             "diesel",
#             10866,
#             0.2929393686140242
#         ],
#         [
#             "lpg",
#             579,
#             0.0156094141751813
#         ],
#         [
#             "hybrid",
#             23,
#             0.0006200630846790499
#         ],
#         [
#             "cng",
#             54,
#             0.0014558002857682042
#         ],
#         [
#             "benzin",
#             22230,
#             0.5993044509745774
#         ]
#     ]
# }
# StandardProfiles for column: notRepairedDamage: {
#     "completeness": 0.8068368694902003,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 7165,
#         "String": 29928
#     },
#     "histogram": [
#         [
#             "ja",
#             3574,
#             0.09635241150621411
#         ],
#         [
#             "nein",
#             26354,
#             0.7104844579839862
#         ],
#         [
#             "NullValue",
#             7165,
#             0.1931631305097997
#         ]
#     ]
# }
# NumericProfiles for column: price: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 1939,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 67930.99929905913,
#     "maximum": 2147483647.0,
#     "minimum": 0.0,
#     "sum": 2519764557.0,
#     "stdDev": 11162960.05891826,
#     "approxPercentiles": []
# }
# StandardProfiles for column: vehicleType: {
#     "completeness": 0.9010055805677621,
#     "approximateNumDistinctValues": 8,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 3672,
#         "String": 33421
#     },
#     "histogram": [
#         [
#             "bus",
#             3089,
#             0.08327716819885153
#         ],
#         [
#             "andere",
#             338,
#             0.009112231418326908
#         ],
#         [
#             "NullValue",
#             3672,
#             0.09899441943223788
#         ],
#         [
#             "kombi",
#             6775,
#             0.1826490173348071
#         ],
#         [
#             "limousine",
#             9723,
#             0.26212492923193054
#         ],
#         [
#             "coupe",
#             1890,
#             0.05095301000188715
#         ],
#         [
#             "cabrio",
#             2246,
#             0.060550508182136795
#         ],
#         [
#             "kleinwagen",
#             7884,
#             0.21254684172215782
#         ],
#         [
#             "suv",
#             1476,
#             0.039791874477664246
#         ]
#     ]
# }
# StandardProfiles for column: dateCrawled: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 36061,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 37093
#     },
#     "histogram": null
# }
# StandardProfiles for column: offerType: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 37093
#     },
#     "histogram": [
#         [
#             "Angebot",
#             37092,
#             0.9999730407354487
#         ],
#         [
#             "Gesuch",
#             1,
#             2.695926455126304e-05
#         ]
#     ]
# }
# StandardProfiles for column: gearbox: {
#     "completeness": 0.9469441673631144,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 1968,
#         "String": 35125
#     },
#     "histogram": [
#         [
#             "manuell",
#             27424,
#             0.7393308710538377
#         ],
#         [
#             "automatik",
#             7701,
#             0.2076132963092767
#         ],
#         [
#             "NullValue",
#             1968,
#             0.053055832636885666
#         ]
#     ]
# }
# NumericProfiles for column: monthOfRegistration: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 13,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "12",
#             2556,
#             0.06890788019302833
#         ],
#         [
#             "8",
#             2343,
#             0.0631655568436093
#         ],
#         [
#             "4",
#             3065,
#             0.08263014584962122
#         ],
#         [
#             "11",
#             2560,
#             0.06901571725123339
#         ],
#         [
#             "9",
#             2546,
#             0.0686382875475157
#         ],
#         [
#             "5",
#             3088,
#             0.08325020893430027
#         ],
#         [
#             "10",
#             2697,
#             0.07270913649475642
#         ],
#         [
#             "6",
#             3283,
#             0.08850726552179657
#         ],
#         [
#             "1",
#             2450,
#             0.06605019815059446
#         ],
#         [
#             "0",
#             3754,
#             0.10120507912544145
#         ],
#         [
#             "2",
#             2241,
#             0.06041571185938047
#         ],
#         [
#             "7",
#             2972,
#             0.08012293424635376
#         ],
#         [
#             "3",
#             3538,
#             0.09538187798236863
#         ]
#     ],
#     "kll": "None",
#     "mean": 5.7479308764456905,
#     "maximum": 12.0,
#     "minimum": 0.0,
#     "sum": 213208.0,
#     "stdDev": 3.71347688761488,
#     "approxPercentiles": []
# }
# StandardProfiles for column: brand: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 42,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 37093
#     },
#     "histogram": [
#         [
#             "suzuki",
#             237,
#             0.006389345698649341
#         ],
#         [
#             "ford",
#             2569,
#             0.06925835063219475
#         ],
#         [
#             "chrysler",
#             147,
#             0.003963011889035667
#         ],
#         [
#             "daewoo",
#             69,
#             0.0018601892540371498
#         ],
#         [
#             "mini",
#             326,
#             0.008788720243711752
#         ],
#         [
#             "porsche",
#             195,
#             0.005257056587496293
#         ],
#         [
#             "chevrolet",
#             181,
#             0.004879626883778611
#         ],
#         [
#             "trabant",
#             63,
#             0.0016984336667295716
#         ],
#         [
#             "alfa_romeo",
#             241,
#             0.006497182756854393
#         ],
#         [
#             "smart",
#             529,
#             0.014261450947618149
#         ],
#         [
#             "honda",
#             277,
#             0.007467716280699863
#         ],
#         [
#             "seat",
#             701,
#             0.01889844445043539
#         ],
#         [
#             "hyundai",
#             376,
#             0.010136683471274903
#         ],
#         [
#             "volkswagen",
#             7953,
#             0.21440703097619496
#         ],
#         [
#             "jeep",
#             85,
#             0.0022915374868573584
#         ],
#         [
#             "audi",
#             3256,
#             0.08777936537891247
#         ],
#         [
#             "opel",
#             3986,
#             0.10745962850133449
#         ],
#         [
#             "lada",
#             24,
#             0.000647022349230313
#         ],
#         [
#             "subaru",
#             61,
#             0.0016445151376270454
#         ],
#         [
#             "citroen",
#             531,
#             0.014315369476720675
#         ],
#         [
#             "lancia",
#             55,
#             0.0014827595503194672
#         ],
#         [
#             "saab",
#             45,
#             0.0012131669048068368
#         ],
#         [
#             "toyota",
#             462,
#             0.012455180222683526
#         ],
#         [
#             "volvo",
#             326,
#             0.008788720243711752
#         ],
#         [
#             "sonstige_autos",
#             385,
#             0.01037931685223627
#         ],
#         [
#             "dacia",
#             99,
#             0.002668967190575041
#         ],
#         [
#             "rover",
#             53,
#             0.001428841021216941
#         ],
#         [
#             "skoda",
#             595,
#             0.01604076240800151
#         ],
#         [
#             "renault",
#             1742,
#             0.04696303884830022
#         ],
#         [
#             "mercedes_benz",
#             3612,
#             0.0973768635591621
#         ],
#         [
#             "bmw",
#             4017,
#             0.10829536570242364
#         ],
#         [
#             "mazda",
#             562,
#             0.01515110667780983
#         ],
#         [
#             "kia",
#             235,
#             0.006335427169546814
#         ],
#         [
#             "mitsubishi",
#             286,
#             0.00771034966166123
#         ],
#         [
#             "jaguar",
#             61,
#             0.0016445151376270454
#         ],
#         [
#             "peugeot",
#             1116,
#             0.030086539239209554
#         ],
#         [
#             "nissan",
#             534,
#             0.014396247270374465
#         ],
#         [
#             "daihatsu",
#             78,
#             0.002102822634998517
#         ],
#         [
#             "land_rover",
#             77,
#             0.0020758633704472543
#         ],
#         [
#             "fiat",
#             946,
#             0.025503464265494838
#         ]
#     ]
# }
# NumericProfiles for column: postalCode: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 6757,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 50728.40066858976,
#     "maximum": 99998.0,
#     "minimum": 1067.0,
#     "sum": 1881668566.0,
#     "stdDev": 25770.66003280647,
#     "approxPercentiles": []
# }
# StandardProfiles for column: dateCreated: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 67,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 37093
#     },
#     "histogram": [
#         [
#             "2016-02-05 00:00:00",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "2016-02-13 00:00:00",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "2016-03-11 00:00:00",
#             1240,
#             0.03342948804356617
#         ],
#         [
#             "2016-04-04 00:00:00",
#             1396,
#             0.037635133313563204
#         ],
#         [
#             "2016-02-15 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-02-10 00:00:00",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "2016-03-08 00:00:00",
#             1246,
#             0.03359124363087375
#         ],
#         [
#             "2015-11-08 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-18 00:00:00",
#             515,
#             0.013884021243900466
#         ],
#         [
#             "2016-03-14 00:00:00",
#             1251,
#             0.03372603995363006
#         ],
#         [
#             "2016-02-18 00:00:00",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "2016-04-01 00:00:00",
#             1283,
#             0.03458873641927048
#         ],
#         [
#             "2016-03-04 00:00:00",
#             56,
#             0.0015097188148707303
#         ],
#         [
#             "2016-03-25 00:00:00",
#             1231,
#             0.033186854662604806
#         ],
#         [
#             "2016-02-09 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-01-17 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-01-30 00:00:00",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "2016-03-26 00:00:00",
#             1137,
#             0.030652683794786077
#         ],
#         [
#             "2016-03-13 00:00:00",
#             682,
#             0.018386218423961393
#         ],
#         [
#             "2016-03-10 00:00:00",
#             1226,
#             0.03305205833984849
#         ],
#         [
#             "2016-04-03 00:00:00",
#             1416,
#             0.03817431860458847
#         ],
#         [
#             "2016-02-28 00:00:00",
#             5,
#             0.0001347963227563152
#         ],
#         [
#             "2016-01-19 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-02-23 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-05 00:00:00",
#             788,
#             0.021243900466395276
#         ],
#         [
#             "2016-03-17 00:00:00",
#             1157,
#             0.031191869085811338
#         ],
#         [
#             "2016-03-16 00:00:00",
#             1167,
#             0.03146146173132397
#         ],
#         [
#             "2016-03-20 00:00:00",
#             1402,
#             0.03779688890087078
#         ],
#         [
#             "2016-01-28 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-01-24 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-31 00:00:00",
#             1201,
#             0.032378076726066914
#         ],
#         [
#             "2016-02-11 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-27 00:00:00",
#             1155,
#             0.031137950556708812
#         ],
#         [
#             "2016-03-22 00:00:00",
#             1179,
#             0.031784972905939124
#         ],
#         [
#             "2016-01-10 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-28 00:00:00",
#             1232,
#             0.03321381392715607
#         ],
#         [
#             "2016-03-09 00:00:00",
#             1336,
#             0.036017577440487426
#         ],
#         [
#             "2016-03-24 00:00:00",
#             1091,
#             0.02941255762542798
#         ],
#         [
#             "2016-03-23 00:00:00",
#             1145,
#             0.030868357911196184
#         ],
#         [
#             "2016-03-29 00:00:00",
#             1265,
#             0.03410346965734775
#         ],
#         [
#             "2016-04-07 00:00:00",
#             51,
#             0.0013749224921144152
#         ],
#         [
#             "2016-03-02 00:00:00",
#             6,
#             0.00016175558730757825
#         ],
#         [
#             "2016-02-24 00:00:00",
#             4,
#             0.00010783705820505216
#         ],
#         [
#             "2016-02-07 00:00:00",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "2016-02-20 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-02-27 00:00:00",
#             3,
#             8.087779365378912e-05
#         ],
#         [
#             "2016-02-29 00:00:00",
#             9,
#             0.00024263338096136737
#         ],
#         [
#             "2016-02-22 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-01 00:00:00",
#             9,
#             0.00024263338096136737
#         ],
#         [
#             "2016-03-21 00:00:00",
#             1336,
#             0.036017577440487426
#         ],
#         [
#             "2016-03-12 00:00:00",
#             1375,
#             0.037068988757986684
#         ],
#         [
#             "2016-03-15 00:00:00",
#             1235,
#             0.03329469172080986
#         ],
#         [
#             "2016-03-03 00:00:00",
#             46,
#             0.0012401261693580998
#         ],
#         [
#             "2016-02-26 00:00:00",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "2016-04-02 00:00:00",
#             1296,
#             0.0349392068584369
#         ],
#         [
#             "2016-02-12 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-30 00:00:00",
#             1189,
#             0.03205456555145176
#         ],
#         [
#             "2016-04-05 00:00:00",
#             429,
#             0.011565524492491845
#         ],
#         [
#             "2016-02-19 00:00:00",
#             4,
#             0.00010783705820505216
#         ],
#         [
#             "2016-04-06 00:00:00",
#             116,
#             0.003127274687946513
#         ],
#         [
#             "2016-02-16 00:00:00",
#             2,
#             5.391852910252608e-05
#         ],
#         [
#             "2016-02-03 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-07 00:00:00",
#             1273,
#             0.03431914377375785
#         ],
#         [
#             "2015-08-10 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-19 00:00:00",
#             1259,
#             0.033941714070040166
#         ],
#         [
#             "2016-01-07 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-01-26 00:00:00",
#             1,
#             2.695926455126304e-05
#         ],
#         [
#             "2016-03-06 00:00:00",
#             618,
#             0.01666082549268056
#         ]
#     ]
# }
# NumericProfiles for column: nrOfPictures: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 1,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "0",
#             37093,
#             1.0
#         ]
#     ],
#     "kll": "None",
#     "mean": 0.0,
#     "maximum": 0.0,
#     "minimum": 0.0,
#     "sum": 0.0,
#     "stdDev": 0.0,
#     "approxPercentiles": []
# }
# NumericProfiles for column: kilometer: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 13,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "80000",
#             1092,
#             0.029439516889979242
#         ],
#         [
#             "125000",
#             3820,
#             0.10298439058582481
#         ],
#         [
#             "60000",
#             893,
#             0.024074623244277896
#         ],
#         [
#             "150000",
#             24069,
#             0.6488825384843502
#         ],
#         [
#             "90000",
#             1222,
#             0.032944221281643433
#         ],
#         [
#             "70000",
#             963,
#             0.02596177176286631
#         ],
#         [
#             "50000",
#             774,
#             0.020866470762677593
#         ],
#         [
#             "100000",
#             1606,
#             0.043296578869328445
#         ],
#         [
#             "20000",
#             577,
#             0.015555495646078775
#         ],
#         [
#             "40000",
#             599,
#             0.016148599466206563
#         ],
#         [
#             "30000",
#             555,
#             0.014962391825950988
#         ],
#         [
#             "5000",
#             719,
#             0.019383711212358126
#         ],
#         [
#             "10000",
#             204,
#             0.005499689968457661
#         ]
#     ],
#     "kll": "None",
#     "mean": 125718.19480764565,
#     "maximum": 150000.0,
#     "minimum": 5000.0,
#     "sum": 4663265000.0,
#     "stdDev": 40059.44053937505,
#     "approxPercentiles": []
# }
# StandardProfiles for column: seller: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 1,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 37093
#     },
#     "histogram": [
#         [
#             "privat",
#             37093,
#             1.0
#         ]
#     ]
# }

# %%
result.columnProfileClasses
# Out:
# {'StandardColumnProfile': pydeequ.profiles.StandardColumnProfile,
#  'NumericColumnProfile': pydeequ.profiles.NumericColumnProfile}

# %%
result.profiles
# Out:
# {'lastSeen': <pydeequ.profiles.StandardColumnProfile at 0x7de888113820>,
#  'name': <pydeequ.profiles.StandardColumnProfile at 0x7de888113580>,
#  'yearOfRegistration': <pydeequ.profiles.NumericColumnProfile at 0x7de888112a10>,
#  'model': <pydeequ.profiles.StandardColumnProfile at 0x7de8880fba00>,
#  'abtest': <pydeequ.profiles.StandardColumnProfile at 0x7de8880f9ff0>,
#  'powerPS': <pydeequ.profiles.NumericColumnProfile at 0x7de888111ba0>,
#  'fuelType': <pydeequ.profiles.StandardColumnProfile at 0x7de888113370>,
#  'notRepairedDamage': <pydeequ.profiles.StandardColumnProfile at 0x7de8880fb9d0>,
#  'price': <pydeequ.profiles.NumericColumnProfile at 0x7de888110f70>,
#  'vehicleType': <pydeequ.profiles.StandardColumnProfile at 0x7de888111b40>,
#  'dateCrawled': <pydeequ.profiles.StandardColumnProfile at 0x7de8880fb4f0>,
#  'offerType': <pydeequ.profiles.StandardColumnProfile at 0x7de8880fac20>,
#  'gearbox': <pydeequ.profiles.StandardColumnProfile at 0x7de888113280>,
#  'monthOfRegistration': <pydeequ.profiles.NumericColumnProfile at 0x7de8880fa380>,
#  'brand': <pydeequ.profiles.StandardColumnProfile at 0x7de8880f9060>,
#  'postalCode': <pydeequ.profiles.NumericColumnProfile at 0x7de8880f89a0>,
#  'dateCreated': <pydeequ.profiles.StandardColumnProfile at 0x7de8880fb100>,
#  'nrOfPictures': <pydeequ.profiles.NumericColumnProfile at 0x7de8880f92a0>,
#  'kilometer': <pydeequ.profiles.NumericColumnProfile at 0x7de8880fa110>,
#  'seller': <pydeequ.profiles.StandardColumnProfile at 0x7de8880fa860>}

# %%
ex_result = ColumnProfilerRunner(spark) \
    .onData(_data.select('name','powerPs')) \
    .run()

# %%
for col, profile in ex_result.profiles.items():
    print(profile)
# Out:
# StandardProfiles for column: name: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 28466,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 8,
#         "Unknown": 0,
#         "String": 37085
#     },
#     "histogram": null
# }
# NumericProfiles for column: powerPs: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 406,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 115.45855013075243,
#     "maximum": 20000.0,
#     "minimum": 0.0,
#     "sum": 4282704.0,
#     "stdDev": 199.11718427917157,
#     "approxPercentiles": []
# }

# %% [markdown]
# ##### [TODO] import the JSON object to a DF to facilitate its processing

# %% [markdown]
# #### constraint suggestion

# %%
from pydeequ.suggestions import *

suggestionResult = ConstraintSuggestionRunner(spark) \
             .onData(_data) \
             .addConstraintRule(DEFAULT()) \
             .run()

# Constraint Suggestions in JSON format
# print(suggestionResult)

# %%
import pprint as pprint
pprint.pprint(suggestionResult)
# Out:
# {'constraint_suggestions': [{'code_for_constraint': '.isComplete("lastSeen")',
#                              'column_name': 'lastSeen',
#                              'constraint_name': 'CompletenessConstraint(Completeness(lastSeen,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'lastSeen' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isComplete("name")',
#                              'column_name': 'name',
#                              'constraint_name': 'CompletenessConstraint(Completeness(name,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'name' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isComplete("yearOfRegistration")',
#                              'column_name': 'yearOfRegistration',
#                              'constraint_name': 'CompletenessConstraint(Completeness(yearOfRegistration,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'yearOfRegistration' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isContainedIn("yearOfRegistration", '
#                                                     '["2000", "1999", "2005", '
#                                                     '"2001", "2006", "2003", '
#                                                     '"2004", "2002", "1998", '
#                                                     '"2007", "2008", "2009", '
#                                                     '"1997", "2010", "2011", '
#                                                     '"1996", "2017", "2016", '
#                                                     '"1995", "2012", "2013", '
#                                                     '"1994"], lambda x: x >= '
#                                                     '0.9, "It should be above '
#                                                     '0.9!")',
#                              'column_name': 'yearOfRegistration',
#                              'constraint_name': "ComplianceConstraint(Compliance('yearOfRegistration' "
#                                                 "has value range '2000', "
#                                                 "'1999', '2005', '2001', "
#                                                 "'2006', '2003', '2004', "
#                                                 "'2002', '1998', '2007', "
#                                                 "'2008', '2009', '1997', "
#                                                 "'2010', '2011', '1996', "
#                                                 "'2017', '2016', '1995', "
#                                                 "'2012', '2013', '1994' for at "
#                                                 'least 90.0% of '
#                                                 'values,`yearOfRegistration` '
#                                                 "IN ('2000', '1999', '2005', "
#                                                 "'2001', '2006', '2003', "
#                                                 "'2004', '2002', '1998', "
#                                                 "'2007', '2008', '2009', "
#                                                 "'1997', '2010', '2011', "
#                                                 "'1996', '2017', '2016', "
#                                                 "'1995', '2012', '2013', "
#                                                 "'1994'),None))",
#                              'current_value': 'Compliance: 0.9072601299436551',
#                              'description': "'yearOfRegistration' has value "
#                                             "range '2000', '1999', '2005', "
#                                             "'2001', '2006', '2003', '2004', "
#                                             "'2002', '1998', '2007', '2008', "
#                                             "'2009', '1997', '2010', '2011', "
#                                             "'1996', '2017', '2016', '1995', "
#                                             "'2012', '2013', '1994' for at "
#                                             'least 90.0% of values',
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.isNonNegative("yearOfRegistration")',
#                              'column_name': 'yearOfRegistration',
#                              'constraint_name': "ComplianceConstraint(Compliance('yearOfRegistration' "
#                                                 'has no negative '
#                                                 'values,yearOfRegistration >= '
#                                                 '0,None))',
#                              'current_value': 'Minimum: 1000.0',
#                              'description': "'yearOfRegistration' has no "
#                                             'negative values',
#                              'rule_description': 'If we see only non-negative '
#                                                  'numbers in a column, we '
#                                                  'suggest a corresponding '
#                                                  'constraint',
#                              'suggesting_rule': 'NonNegativeNumbersRule()'},
#                             {'code_for_constraint': '.hasCompleteness("model", '
#                                                     'lambda x: x >= 0.94, "It '
#                                                     'should be above 0.94!")',
#                              'column_name': 'model',
#                              'constraint_name': 'CompletenessConstraint(Completeness(model,None))',
#                              'current_value': 'Completeness: '
#                                               '0.9454074892836923',
#                              'description': "'model' has less than 6% missing "
#                                             'values',
#                              'rule_description': 'If a column is incomplete in '
#                                                  'the sample, we model its '
#                                                  'completeness as a binomial '
#                                                  'variable, estimate a '
#                                                  'confidence interval and use '
#                                                  'this to define a lower bound '
#                                                  'for the completeness',
#                              'suggesting_rule': 'RetainCompletenessRule()'},
#                             {'code_for_constraint': '.isContainedIn("abtest", '
#                                                     '["test", "control"])',
#                              'column_name': 'abtest',
#                              'constraint_name': "ComplianceConstraint(Compliance('abtest' "
#                                                 "has value range 'test', "
#                                                 "'control',`abtest` IN "
#                                                 "('test', 'control'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'abtest' has value range 'test', "
#                                             "'control'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isComplete("abtest")',
#                              'column_name': 'abtest',
#                              'constraint_name': 'CompletenessConstraint(Completeness(abtest,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'abtest' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isComplete("powerPS")',
#                              'column_name': 'powerPS',
#                              'constraint_name': 'CompletenessConstraint(Completeness(powerPS,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'powerPS' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isNonNegative("powerPS")',
#                              'column_name': 'powerPS',
#                              'constraint_name': "ComplianceConstraint(Compliance('powerPS' "
#                                                 'has no negative '
#                                                 'values,powerPS >= 0,None))',
#                              'current_value': 'Minimum: 0.0',
#                              'description': "'powerPS' has no negative values",
#                              'rule_description': 'If we see only non-negative '
#                                                  'numbers in a column, we '
#                                                  'suggest a corresponding '
#                                                  'constraint',
#                              'suggesting_rule': 'NonNegativeNumbersRule()'},
#                             {'code_for_constraint': '.isContainedIn("fuelType", '
#                                                     '["benzin", "diesel", '
#                                                     '"lpg", "cng", "hybrid", '
#                                                     '"andere", "elektro"])',
#                              'column_name': 'fuelType',
#                              'constraint_name': "ComplianceConstraint(Compliance('fuelType' "
#                                                 "has value range 'benzin', "
#                                                 "'diesel', 'lpg', 'cng', "
#                                                 "'hybrid', 'andere', "
#                                                 "'elektro',`fuelType` IN "
#                                                 "('benzin', 'diesel', 'lpg', "
#                                                 "'cng', 'hybrid', 'andere', "
#                                                 "'elektro'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'fuelType' has value range "
#                                             "'benzin', 'diesel', 'lpg', 'cng', "
#                                             "'hybrid', 'andere', 'elektro'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isContainedIn("fuelType", '
#                                                     '["benzin", "diesel"], '
#                                                     'lambda x: x >= 0.98, "It '
#                                                     'should be above 0.98!")',
#                              'column_name': 'fuelType',
#                              'constraint_name': "ComplianceConstraint(Compliance('fuelType' "
#                                                 "has value range 'benzin', "
#                                                 "'diesel' for at least 98.0% "
#                                                 'of values,`fuelType` IN '
#                                                 "('benzin', 'diesel'),None))",
#                              'current_value': 'Compliance: 0.9815059445178335',
#                              'description': "'fuelType' has value range "
#                                             "'benzin', 'diesel' for at least "
#                                             '98.0% of values',
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.hasCompleteness("fuelType", '
#                                                     'lambda x: x >= 0.9, "It '
#                                                     'should be above 0.9!")',
#                              'column_name': 'fuelType',
#                              'constraint_name': 'CompletenessConstraint(Completeness(fuelType,None))',
#                              'current_value': 'Completeness: '
#                                               '0.9107378750707681',
#                              'description': "'fuelType' has less than 9% "
#                                             'missing values',
#                              'rule_description': 'If a column is incomplete in '
#                                                  'the sample, we model its '
#                                                  'completeness as a binomial '
#                                                  'variable, estimate a '
#                                                  'confidence interval and use '
#                                                  'this to define a lower bound '
#                                                  'for the completeness',
#                              'suggesting_rule': 'RetainCompletenessRule()'},
#                             {'code_for_constraint': '.isContainedIn("notRepairedDamage", '
#                                                     '["nein", "ja"])',
#                              'column_name': 'notRepairedDamage',
#                              'constraint_name': "ComplianceConstraint(Compliance('notRepairedDamage' "
#                                                 "has value range 'nein', "
#                                                 "'ja',`notRepairedDamage` IN "
#                                                 "('nein', 'ja'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'notRepairedDamage' has value "
#                                             "range 'nein', 'ja'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isContainedIn("notRepairedDamage", '
#                                                     '["nein"], lambda x: x >= '
#                                                     '0.9, "It should be above '
#                                                     '0.9!")',
#                              'column_name': 'notRepairedDamage',
#                              'constraint_name': "ComplianceConstraint(Compliance('notRepairedDamage' "
#                                                 "has value range 'nein' for at "
#                                                 'least 90.0% of '
#                                                 'values,`notRepairedDamage` IN '
#                                                 "('nein'),None))",
#                              'current_value': 'Compliance: 0.9036475884937859',
#                              'description': "'notRepairedDamage' has value "
#                                             "range 'nein' for at least 90.0% "
#                                             'of values',
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.hasCompleteness("notRepairedDamage", '
#                                                     'lambda x: x >= 0.8, "It '
#                                                     'should be above 0.8!")',
#                              'column_name': 'notRepairedDamage',
#                              'constraint_name': 'CompletenessConstraint(Completeness(notRepairedDamage,None))',
#                              'current_value': 'Completeness: '
#                                               '0.8068368694902003',
#                              'description': "'notRepairedDamage' has less than "
#                                             '19% missing values',
#                              'rule_description': 'If a column is incomplete in '
#                                                  'the sample, we model its '
#                                                  'completeness as a binomial '
#                                                  'variable, estimate a '
#                                                  'confidence interval and use '
#                                                  'this to define a lower bound '
#                                                  'for the completeness',
#                              'suggesting_rule': 'RetainCompletenessRule()'},
#                             {'code_for_constraint': '.isComplete("price")',
#                              'column_name': 'price',
#                              'constraint_name': 'CompletenessConstraint(Completeness(price,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'price' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isNonNegative("price")',
#                              'column_name': 'price',
#                              'constraint_name': "ComplianceConstraint(Compliance('price' "
#                                                 'has no negative values,price '
#                                                 '>= 0,None))',
#                              'current_value': 'Minimum: 0.0',
#                              'description': "'price' has no negative values",
#                              'rule_description': 'If we see only non-negative '
#                                                  'numbers in a column, we '
#                                                  'suggest a corresponding '
#                                                  'constraint',
#                              'suggesting_rule': 'NonNegativeNumbersRule()'},
#                             {'code_for_constraint': '.isContainedIn("vehicleType", '
#                                                     '["limousine", '
#                                                     '"kleinwagen", "kombi", '
#                                                     '"bus", "cabrio", "coupe", '
#                                                     '"suv", "andere"])',
#                              'column_name': 'vehicleType',
#                              'constraint_name': "ComplianceConstraint(Compliance('vehicleType' "
#                                                 "has value range 'limousine', "
#                                                 "'kleinwagen', 'kombi', 'bus', "
#                                                 "'cabrio', 'coupe', 'suv', "
#                                                 "'andere',`vehicleType` IN "
#                                                 "('limousine', 'kleinwagen', "
#                                                 "'kombi', 'bus', 'cabrio', "
#                                                 "'coupe', 'suv', "
#                                                 "'andere'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'vehicleType' has value range "
#                                             "'limousine', 'kleinwagen', "
#                                             "'kombi', 'bus', 'cabrio', "
#                                             "'coupe', 'suv', 'andere'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isContainedIn("vehicleType", '
#                                                     '["limousine", '
#                                                     '"kleinwagen", "kombi", '
#                                                     '"bus", "cabrio"], lambda '
#                                                     'x: x >= 0.89, "It should '
#                                                     'be above 0.89!")',
#                              'column_name': 'vehicleType',
#                              'constraint_name': "ComplianceConstraint(Compliance('vehicleType' "
#                                                 "has value range 'limousine', "
#                                                 "'kleinwagen', 'kombi', 'bus', "
#                                                 "'cabrio' for at least 89.0% "
#                                                 'of values,`vehicleType` IN '
#                                                 "('limousine', 'kleinwagen', "
#                                                 "'kombi', 'bus', "
#                                                 "'cabrio'),None))",
#                              'current_value': 'Compliance: 0.9001428841021217',
#                              'description': "'vehicleType' has value range "
#                                             "'limousine', 'kleinwagen', "
#                                             "'kombi', 'bus', 'cabrio' for at "
#                                             'least 89.0% of values',
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.hasCompleteness("vehicleType", '
#                                                     'lambda x: x >= 0.89, "It '
#                                                     'should be above 0.89!")',
#                              'column_name': 'vehicleType',
#                              'constraint_name': 'CompletenessConstraint(Completeness(vehicleType,None))',
#                              'current_value': 'Completeness: '
#                                               '0.9010055805677621',
#                              'description': "'vehicleType' has less than 10% "
#                                             'missing values',
#                              'rule_description': 'If a column is incomplete in '
#                                                  'the sample, we model its '
#                                                  'completeness as a binomial '
#                                                  'variable, estimate a '
#                                                  'confidence interval and use '
#                                                  'this to define a lower bound '
#                                                  'for the completeness',
#                              'suggesting_rule': 'RetainCompletenessRule()'},
#                             {'code_for_constraint': '.isComplete("dateCrawled")',
#                              'column_name': 'dateCrawled',
#                              'constraint_name': 'CompletenessConstraint(Completeness(dateCrawled,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'dateCrawled' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isUnique("dateCrawled")',
#                              'column_name': 'dateCrawled',
#                              'constraint_name': 'UniquenessConstraint(Uniqueness(List(dateCrawled),None))',
#                              'current_value': 'ApproxDistinctness: '
#                                               '0.9721780389830965',
#                              'description': "'dateCrawled' is unique",
#                              'rule_description': 'If the ratio of approximate '
#                                                  'num distinct values in a '
#                                                  'column is close to the '
#                                                  'number of records (within '
#                                                  'the error of the HLL '
#                                                  'sketch), we suggest a UNIQUE '
#                                                  'constraint',
#                              'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()'},
#                             {'code_for_constraint': '.isComplete("offerType")',
#                              'column_name': 'offerType',
#                              'constraint_name': 'CompletenessConstraint(Completeness(offerType,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'offerType' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isContainedIn("gearbox", '
#                                                     '["manuell", "automatik"])',
#                              'column_name': 'gearbox',
#                              'constraint_name': "ComplianceConstraint(Compliance('gearbox' "
#                                                 "has value range 'manuell', "
#                                                 "'automatik',`gearbox` IN "
#                                                 "('manuell', "
#                                                 "'automatik'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'gearbox' has value range "
#                                             "'manuell', 'automatik'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isContainedIn("gearbox", '
#                                                     '["manuell", "automatik"], '
#                                                     'lambda x: x >= 0.94, "It '
#                                                     'should be above 0.94!")',
#                              'column_name': 'gearbox',
#                              'constraint_name': "ComplianceConstraint(Compliance('gearbox' "
#                                                 "has value range 'manuell', "
#                                                 "'automatik' for at least "
#                                                 '94.0% of values,`gearbox` IN '
#                                                 "('manuell', "
#                                                 "'automatik'),None))",
#                              'current_value': 'Compliance: 0.9469441673631144',
#                              'description': "'gearbox' has value range "
#                                             "'manuell', 'automatik' for at "
#                                             'least 94.0% of values',
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.hasCompleteness("gearbox", '
#                                                     'lambda x: x >= 0.94, "It '
#                                                     'should be above 0.94!")',
#                              'column_name': 'gearbox',
#                              'constraint_name': 'CompletenessConstraint(Completeness(gearbox,None))',
#                              'current_value': 'Completeness: '
#                                               '0.9469441673631144',
#                              'description': "'gearbox' has less than 6% "
#                                             'missing values',
#                              'rule_description': 'If a column is incomplete in '
#                                                  'the sample, we model its '
#                                                  'completeness as a binomial '
#                                                  'variable, estimate a '
#                                                  'confidence interval and use '
#                                                  'this to define a lower bound '
#                                                  'for the completeness',
#                              'suggesting_rule': 'RetainCompletenessRule()'},
#                             {'code_for_constraint': '.isContainedIn("monthOfRegistration", '
#                                                     '["0", "3", "6", "5", "4", '
#                                                     '"7", "10", "11", "12", '
#                                                     '"9", "1", "8", "2"])',
#                              'column_name': 'monthOfRegistration',
#                              'constraint_name': "ComplianceConstraint(Compliance('monthOfRegistration' "
#                                                 "has value range '0', '3', "
#                                                 "'6', '5', '4', '7', '10', "
#                                                 "'11', '12', '9', '1', '8', "
#                                                 "'2',`monthOfRegistration` IN "
#                                                 "('0', '3', '6', '5', '4', "
#                                                 "'7', '10', '11', '12', '9', "
#                                                 "'1', '8', '2'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'monthOfRegistration' has value "
#                                             "range '0', '3', '6', '5', '4', "
#                                             "'7', '10', '11', '12', '9', '1', "
#                                             "'8', '2'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isComplete("monthOfRegistration")',
#                              'column_name': 'monthOfRegistration',
#                              'constraint_name': 'CompletenessConstraint(Completeness(monthOfRegistration,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'monthOfRegistration' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isContainedIn("monthOfRegistration", '
#                                                     '["0", "3", "6", "5", "4", '
#                                                     '"7", "10", "11", "12", '
#                                                     '"9", "1", "8"], lambda x: '
#                                                     'x >= 0.93, "It should be '
#                                                     'above 0.93!")',
#                              'column_name': 'monthOfRegistration',
#                              'constraint_name': "ComplianceConstraint(Compliance('monthOfRegistration' "
#                                                 "has value range '0', '3', "
#                                                 "'6', '5', '4', '7', '10', "
#                                                 "'11', '12', '9', '1', '8' for "
#                                                 'at least 93.0% of '
#                                                 'values,`monthOfRegistration` '
#                                                 "IN ('0', '3', '6', '5', '4', "
#                                                 "'7', '10', '11', '12', '9', "
#                                                 "'1', '8'),None))",
#                              'current_value': 'Compliance: 0.9395842881406195',
#                              'description': "'monthOfRegistration' has value "
#                                             "range '0', '3', '6', '5', '4', "
#                                             "'7', '10', '11', '12', '9', '1', "
#                                             "'8' for at least 93.0% of values",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.isNonNegative("monthOfRegistration")',
#                              'column_name': 'monthOfRegistration',
#                              'constraint_name': "ComplianceConstraint(Compliance('monthOfRegistration' "
#                                                 'has no negative '
#                                                 'values,monthOfRegistration >= '
#                                                 '0,None))',
#                              'current_value': 'Minimum: 0.0',
#                              'description': "'monthOfRegistration' has no "
#                                             'negative values',
#                              'rule_description': 'If we see only non-negative '
#                                                  'numbers in a column, we '
#                                                  'suggest a corresponding '
#                                                  'constraint',
#                              'suggesting_rule': 'NonNegativeNumbersRule()'},
#                             {'code_for_constraint': '.isContainedIn("brand", '
#                                                     '["volkswagen", "bmw", '
#                                                     '"opel", "mercedes_benz", '
#                                                     '"audi", "ford", '
#                                                     '"renault", "peugeot", '
#                                                     '"fiat", "seat", "skoda", '
#                                                     '"mazda", "nissan", '
#                                                     '"citroen", "smart", '
#                                                     '"toyota", '
#                                                     '"sonstige_autos", '
#                                                     '"hyundai", "volvo", '
#                                                     '"mini", "mitsubishi", '
#                                                     '"honda", "alfa_romeo", '
#                                                     '"suzuki", "kia", '
#                                                     '"porsche", "chevrolet", '
#                                                     '"chrysler", "dacia", '
#                                                     '"jeep", "daihatsu", '
#                                                     '"land_rover", "daewoo", '
#                                                     '"trabant", "jaguar", '
#                                                     '"subaru", "lancia", '
#                                                     '"rover", "saab", "lada"])',
#                              'column_name': 'brand',
#                              'constraint_name': "ComplianceConstraint(Compliance('brand' "
#                                                 "has value range 'volkswagen', "
#                                                 "'bmw', 'opel', "
#                                                 "'mercedes_benz', 'audi', "
#                                                 "'ford', 'renault', 'peugeot', "
#                                                 "'fiat', 'seat', 'skoda', "
#                                                 "'mazda', 'nissan', 'citroen', "
#                                                 "'smart', 'toyota', "
#                                                 "'sonstige_autos', 'hyundai', "
#                                                 "'volvo', 'mini', "
#                                                 "'mitsubishi', 'honda', "
#                                                 "'alfa_romeo', 'suzuki', "
#                                                 "'kia', 'porsche', "
#                                                 "'chevrolet', 'chrysler', "
#                                                 "'dacia', 'jeep', 'daihatsu', "
#                                                 "'land_rover', 'daewoo', "
#                                                 "'trabant', 'jaguar', "
#                                                 "'subaru', 'lancia', 'rover', "
#                                                 "'saab', 'lada',`brand` IN "
#                                                 "('volkswagen', 'bmw', 'opel', "
#                                                 "'mercedes_benz', 'audi', "
#                                                 "'ford', 'renault', 'peugeot', "
#                                                 "'fiat', 'seat', 'skoda', "
#                                                 "'mazda', 'nissan', 'citroen', "
#                                                 "'smart', 'toyota', "
#                                                 "'sonstige_autos', 'hyundai', "
#                                                 "'volvo', 'mini', "
#                                                 "'mitsubishi', 'honda', "
#                                                 "'alfa_romeo', 'suzuki', "
#                                                 "'kia', 'porsche', "
#                                                 "'chevrolet', 'chrysler', "
#                                                 "'dacia', 'jeep', 'daihatsu', "
#                                                 "'land_rover', 'daewoo', "
#                                                 "'trabant', 'jaguar', "
#                                                 "'subaru', 'lancia', 'rover', "
#                                                 "'saab', 'lada'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'brand' has value range "
#                                             "'volkswagen', 'bmw', 'opel', "
#                                             "'mercedes_benz', 'audi', 'ford', "
#                                             "'renault', 'peugeot', 'fiat', "
#                                             "'seat', 'skoda', 'mazda', "
#                                             "'nissan', 'citroen', 'smart', "
#                                             "'toyota', 'sonstige_autos', "
#                                             "'hyundai', 'volvo', 'mini', "
#                                             "'mitsubishi', 'honda', "
#                                             "'alfa_romeo', 'suzuki', 'kia', "
#                                             "'porsche', 'chevrolet', "
#                                             "'chrysler', 'dacia', 'jeep', "
#                                             "'daihatsu', 'land_rover', "
#                                             "'daewoo', 'trabant', 'jaguar', "
#                                             "'subaru', 'lancia', 'rover', "
#                                             "'saab', 'lada'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isComplete("brand")',
#                              'column_name': 'brand',
#                              'constraint_name': 'CompletenessConstraint(Completeness(brand,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'brand' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isContainedIn("brand", '
#                                                     '["volkswagen", "bmw", '
#                                                     '"opel", "mercedes_benz", '
#                                                     '"audi", "ford", '
#                                                     '"renault", "peugeot", '
#                                                     '"fiat", "seat", "skoda", '
#                                                     '"mazda", "nissan", '
#                                                     '"citroen", "smart", '
#                                                     '"toyota", '
#                                                     '"sonstige_autos"], lambda '
#                                                     'x: x >= 0.9, "It should '
#                                                     'be above 0.9!")',
#                              'column_name': 'brand',
#                              'constraint_name': "ComplianceConstraint(Compliance('brand' "
#                                                 "has value range 'volkswagen', "
#                                                 "'bmw', 'opel', "
#                                                 "'mercedes_benz', 'audi', "
#                                                 "'ford', 'renault', 'peugeot', "
#                                                 "'fiat', 'seat', 'skoda', "
#                                                 "'mazda', 'nissan', 'citroen', "
#                                                 "'smart', 'toyota', "
#                                                 "'sonstige_autos' for at least "
#                                                 '90.0% of values,`brand` IN '
#                                                 "('volkswagen', 'bmw', 'opel', "
#                                                 "'mercedes_benz', 'audi', "
#                                                 "'ford', 'renault', 'peugeot', "
#                                                 "'fiat', 'seat', 'skoda', "
#                                                 "'mazda', 'nissan', 'citroen', "
#                                                 "'smart', 'toyota', "
#                                                 "'sonstige_autos'),None))",
#                              'current_value': 'Compliance: 0.9030275254091068',
#                              'description': "'brand' has value range "
#                                             "'volkswagen', 'bmw', 'opel', "
#                                             "'mercedes_benz', 'audi', 'ford', "
# ...
#                                                 "00:00:00', '2016-03-22 "
#                                                 "00:00:00', '2016-03-16 "
#                                                 "00:00:00', '2016-03-17 "
#                                                 "00:00:00', '2016-03-27 "
#                                                 "00:00:00', '2016-03-23 "
#                                                 "00:00:00', '2016-03-26 "
#                                                 "00:00:00', '2016-03-24 "
#                                                 "00:00:00' for at least 90.0% "
#                                                 'of values,`dateCreated` IN '
#                                                 "('2016-04-03 00:00:00', "
#                                                 "'2016-03-20 00:00:00', "
#                                                 "'2016-04-04 00:00:00', "
#                                                 "'2016-03-12 00:00:00', "
#                                                 "'2016-03-21 00:00:00', "
#                                                 "'2016-03-09 00:00:00', "
#                                                 "'2016-04-02 00:00:00', "
#                                                 "'2016-04-01 00:00:00', "
#                                                 "'2016-03-07 00:00:00', "
#                                                 "'2016-03-29 00:00:00', "
#                                                 "'2016-03-19 00:00:00', "
#                                                 "'2016-03-14 00:00:00', "
#                                                 "'2016-03-08 00:00:00', "
#                                                 "'2016-03-11 00:00:00', "
#                                                 "'2016-03-15 00:00:00', "
#                                                 "'2016-03-28 00:00:00', "
#                                                 "'2016-03-25 00:00:00', "
#                                                 "'2016-03-10 00:00:00', "
#                                                 "'2016-03-31 00:00:00', "
#                                                 "'2016-03-30 00:00:00', "
#                                                 "'2016-03-22 00:00:00', "
#                                                 "'2016-03-16 00:00:00', "
#                                                 "'2016-03-17 00:00:00', "
#                                                 "'2016-03-27 00:00:00', "
#                                                 "'2016-03-23 00:00:00', "
#                                                 "'2016-03-26 00:00:00', "
#                                                 "'2016-03-24 00:00:00'),None))",
#                              'current_value': 'Compliance: 0.9090394414040386',
#                              'description': "'dateCreated' has value range "
#                                             "'2016-04-03 00:00:00', "
#                                             "'2016-03-20 00:00:00', "
#                                             "'2016-04-04 00:00:00', "
#                                             "'2016-03-12 00:00:00', "
#                                             "'2016-03-21 00:00:00', "
#                                             "'2016-03-09 00:00:00', "
#                                             "'2016-04-02 00:00:00', "
#                                             "'2016-04-01 00:00:00', "
#                                             "'2016-03-07 00:00:00', "
#                                             "'2016-03-29 00:00:00', "
#                                             "'2016-03-19 00:00:00', "
#                                             "'2016-03-14 00:00:00', "
#                                             "'2016-03-08 00:00:00', "
#                                             "'2016-03-11 00:00:00', "
#                                             "'2016-03-15 00:00:00', "
#                                             "'2016-03-28 00:00:00', "
#                                             "'2016-03-25 00:00:00', "
#                                             "'2016-03-10 00:00:00', "
#                                             "'2016-03-31 00:00:00', "
#                                             "'2016-03-30 00:00:00', "
#                                             "'2016-03-22 00:00:00', "
#                                             "'2016-03-16 00:00:00', "
#                                             "'2016-03-17 00:00:00', "
#                                             "'2016-03-27 00:00:00', "
#                                             "'2016-03-23 00:00:00', "
#                                             "'2016-03-26 00:00:00', "
#                                             "'2016-03-24 00:00:00' for at "
#                                             'least 90.0% of values',
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.isContainedIn("nrOfPictures", '
#                                                     '["0"])',
#                              'column_name': 'nrOfPictures',
#                              'constraint_name': "ComplianceConstraint(Compliance('nrOfPictures' "
#                                                 'has value range '
#                                                 "'0',`nrOfPictures` IN "
#                                                 "('0'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'nrOfPictures' has value range "
#                                             "'0'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isComplete("nrOfPictures")',
#                              'column_name': 'nrOfPictures',
#                              'constraint_name': 'CompletenessConstraint(Completeness(nrOfPictures,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'nrOfPictures' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isNonNegative("nrOfPictures")',
#                              'column_name': 'nrOfPictures',
#                              'constraint_name': "ComplianceConstraint(Compliance('nrOfPictures' "
#                                                 'has no negative '
#                                                 'values,nrOfPictures >= '
#                                                 '0,None))',
#                              'current_value': 'Minimum: 0.0',
#                              'description': "'nrOfPictures' has no negative "
#                                             'values',
#                              'rule_description': 'If we see only non-negative '
#                                                  'numbers in a column, we '
#                                                  'suggest a corresponding '
#                                                  'constraint',
#                              'suggesting_rule': 'NonNegativeNumbersRule()'},
#                             {'code_for_constraint': '.isContainedIn("kilometer", '
#                                                     '["150000", "125000", '
#                                                     '"100000", "90000", '
#                                                     '"80000", "70000", '
#                                                     '"60000", "50000", "5000", '
#                                                     '"40000", "20000", '
#                                                     '"30000", "10000"])',
#                              'column_name': 'kilometer',
#                              'constraint_name': "ComplianceConstraint(Compliance('kilometer' "
#                                                 "has value range '150000', "
#                                                 "'125000', '100000', '90000', "
#                                                 "'80000', '70000', '60000', "
#                                                 "'50000', '5000', '40000', "
#                                                 "'20000', '30000', "
#                                                 "'10000',`kilometer` IN "
#                                                 "('150000', '125000', "
#                                                 "'100000', '90000', '80000', "
#                                                 "'70000', '60000', '50000', "
#                                                 "'5000', '40000', '20000', "
#                                                 "'30000', '10000'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'kilometer' has value range "
#                                             "'150000', '125000', '100000', "
#                                             "'90000', '80000', '70000', "
#                                             "'60000', '50000', '5000', "
#                                             "'40000', '20000', '30000', "
#                                             "'10000'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isComplete("kilometer")',
#                              'column_name': 'kilometer',
#                              'constraint_name': 'CompletenessConstraint(Completeness(kilometer,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'kilometer' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isContainedIn("kilometer", '
#                                                     '["150000", "125000", '
#                                                     '"100000", "90000", '
#                                                     '"80000", "70000", '
#                                                     '"60000"], lambda x: x >= '
#                                                     '0.9, "It should be above '
#                                                     '0.9!")',
#                              'column_name': 'kilometer',
#                              'constraint_name': "ComplianceConstraint(Compliance('kilometer' "
#                                                 "has value range '150000', "
#                                                 "'125000', '100000', '90000', "
#                                                 "'80000', '70000', '60000' for "
#                                                 'at least 90.0% of '
#                                                 'values,`kilometer` IN '
#                                                 "('150000', '125000', "
#                                                 "'100000', '90000', '80000', "
#                                                 "'70000', '60000'),None))",
#                              'current_value': 'Compliance: 0.9075836411182703',
#                              'description': "'kilometer' has value range "
#                                             "'150000', '125000', '100000', "
#                                             "'90000', '80000', '70000', "
#                                             "'60000' for at least 90.0% of "
#                                             'values',
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.isNonNegative("kilometer")',
#                              'column_name': 'kilometer',
#                              'constraint_name': "ComplianceConstraint(Compliance('kilometer' "
#                                                 'has no negative '
#                                                 'values,kilometer >= 0,None))',
#                              'current_value': 'Minimum: 5000.0',
#                              'description': "'kilometer' has no negative "
#                                             'values',
#                              'rule_description': 'If we see only non-negative '
#                                                  'numbers in a column, we '
#                                                  'suggest a corresponding '
#                                                  'constraint',
#                              'suggesting_rule': 'NonNegativeNumbersRule()'},
#                             {'code_for_constraint': '.isContainedIn("seller", '
#                                                     '["privat"])',
#                              'column_name': 'seller',
#                              'constraint_name': "ComplianceConstraint(Compliance('seller' "
#                                                 'has value range '
#                                                 "'privat',`seller` IN "
#                                                 "('privat'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'seller' has value range 'privat'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isComplete("seller")',
#                              'column_name': 'seller',
#                              'constraint_name': 'CompletenessConstraint(Completeness(seller,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'seller' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'}]}

# %%
from pydeequ.suggestions import *

suggestionResult = ConstraintSuggestionRunner(spark) \
             .onData(_data.select('fuelType','powerPs')) \
             .addConstraintRule(DEFAULT()) \
             .run()

# Constraint Suggestions in JSON format
pprint.pprint(suggestionResult)
# Out:
# {'constraint_suggestions': [{'code_for_constraint': '.isContainedIn("fuelType", '
#                                                     '["benzin", "diesel", '
#                                                     '"lpg", "cng", "hybrid", '
#                                                     '"andere", "elektro"])',
#                              'column_name': 'fuelType',
#                              'constraint_name': "ComplianceConstraint(Compliance('fuelType' "
#                                                 "has value range 'benzin', "
#                                                 "'diesel', 'lpg', 'cng', "
#                                                 "'hybrid', 'andere', "
#                                                 "'elektro',`fuelType` IN "
#                                                 "('benzin', 'diesel', 'lpg', "
#                                                 "'cng', 'hybrid', 'andere', "
#                                                 "'elektro'),None))",
#                              'current_value': 'Compliance: 1',
#                              'description': "'fuelType' has value range "
#                                             "'benzin', 'diesel', 'lpg', 'cng', "
#                                             "'hybrid', 'andere', 'elektro'",
#                              'rule_description': 'If we see a categorical '
#                                                  'range for a column, we '
#                                                  'suggest an IS IN (...) '
#                                                  'constraint',
#                              'suggesting_rule': 'CategoricalRangeRule()'},
#                             {'code_for_constraint': '.isContainedIn("fuelType", '
#                                                     '["benzin", "diesel"], '
#                                                     'lambda x: x >= 0.98, "It '
#                                                     'should be above 0.98!")',
#                              'column_name': 'fuelType',
#                              'constraint_name': "ComplianceConstraint(Compliance('fuelType' "
#                                                 "has value range 'benzin', "
#                                                 "'diesel' for at least 98.0% "
#                                                 'of values,`fuelType` IN '
#                                                 "('benzin', 'diesel'),None))",
#                              'current_value': 'Compliance: 0.9815059445178335',
#                              'description': "'fuelType' has value range "
#                                             "'benzin', 'diesel' for at least "
#                                             '98.0% of values',
#                              'rule_description': 'If we see a categorical '
#                                                  'range for most values in a '
#                                                  'column, we suggest an IS IN '
#                                                  '(...) constraint that should '
#                                                  'hold for most values',
#                              'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)'},
#                             {'code_for_constraint': '.hasCompleteness("fuelType", '
#                                                     'lambda x: x >= 0.9, "It '
#                                                     'should be above 0.9!")',
#                              'column_name': 'fuelType',
#                              'constraint_name': 'CompletenessConstraint(Completeness(fuelType,None))',
#                              'current_value': 'Completeness: '
#                                               '0.9107378750707681',
#                              'description': "'fuelType' has less than 9% "
#                                             'missing values',
#                              'rule_description': 'If a column is incomplete in '
#                                                  'the sample, we model its '
#                                                  'completeness as a binomial '
#                                                  'variable, estimate a '
#                                                  'confidence interval and use '
#                                                  'this to define a lower bound '
#                                                  'for the completeness',
#                              'suggesting_rule': 'RetainCompletenessRule()'},
#                             {'code_for_constraint': '.isComplete("powerPs")',
#                              'column_name': 'powerPs',
#                              'constraint_name': 'CompletenessConstraint(Completeness(powerPs,None))',
#                              'current_value': 'Completeness: 1.0',
#                              'description': "'powerPs' is not null",
#                              'rule_description': 'If a column is complete in '
#                                                  'the sample, we suggest a NOT '
#                                                  'NULL constraint',
#                              'suggesting_rule': 'CompleteIfCompleteRule()'},
#                             {'code_for_constraint': '.isNonNegative("powerPs")',
#                              'column_name': 'powerPs',
#                              'constraint_name': "ComplianceConstraint(Compliance('powerPs' "
#                                                 'has no negative '
#                                                 'values,powerPs >= 0,None))',
#                              'current_value': 'Minimum: 0.0',
#                              'description': "'powerPs' has no negative values",
#                              'rule_description': 'If we see only non-negative '
#                                                  'numbers in a column, we '
#                                                  'suggest a corresponding '
#                                                  'constraint',
#                              'suggesting_rule': 'NonNegativeNumbersRule()'}]}

# %% [markdown]
# ##### [TODO] import the JSON object to a DF to facilitate its processing

# %% [markdown]
# #### constraint verification

# %%
from pydeequ.checks import *
from pydeequ.verification import *

check = Check(spark, CheckLevel.Warning, "Review Check")

checkResult = VerificationSuite(spark) \
    .onData(_data) \
    .addCheck(
        check
        .isComplete('price')  \
        .isNonNegative('price')  \
        .isUnique('seller'))\
    .run()

# %%
checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult)
checkResult_df.show()#truncate=False)
# Out:
# +------------+-----------+------------+--------------------+-----------------+--------------------+
# |       check|check_level|check_status|          constraint|constraint_status|  constraint_message|
# +------------+-----------+------------+--------------------+-----------------+--------------------+
# |Review Check|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |Review Check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |Review Check|    Warning|     Warning|UniquenessConstra...|          Failure|Value: 0.0 does n...|
# +------------+-----------+------------+--------------------+-----------------+--------------------+
